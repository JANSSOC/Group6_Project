# %%
# %matplotlib notebook

import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "Project 1 CSV Data/2010-2017-NC-County-Population-Estimates_by_year.csv"
data = pd.read_csv(path, names=["FIPS Code","State and County Names", "April 1 2010 Estimates Base", "July 1 2010 Estimate", "July 1 2011 Estimate", "July 1 2012 Estimate", "July 1 2013 Estimate", "July 1 2014 Estimate","July 1 2015 Estimate", "July 1 2016 Estimate", "July 1 2017 Estimate"])
data.head(10)
# Out:
#                                                                                                                                     FIPS Code  \
# Population Estimates for NC State and Counties,... NaN              NaN                          NaN                                      NaN
# Source: U.S. Census Bureau, Population Estimate... NaN              NaN                          NaN                                      NaN
# NaN                                                NaN              NaN                          NaN                                      NaN
# FIPS Code                                          Geography Name   Total Population             NaN                                      NaN
# NaN                                                NaN              April 1, 2010 Estimates Base July 1, 2010 Estimate  July 1, 2011 Estimate
# ...

# %%
drop_data = data.dropna(axis = 1)
drop_data.head(15)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Population Estimates for NC State and Counties, 2010-2017, nan, nan, nan), (Source: U.S. Census Bureau, Population Estimates Program, nan, nan, nan), (nan, nan, nan, nan), (FIPS Code, Geography Name, Total Population, nan), (nan, nan, April 1, 2010 Estimates Base, July 1, 2010 Estimate), (37000, North Carolina, 9,535,721, 9,574,247), (37001, Alamance County, 151,198, 151,490), (37003, Alexander County, 37,192, 37,241), (37005, Alleghany County, 11,154, 11,141), (37007, Anson County, 26,928, 26,851), (37009, Ashe County, 27,238, 27,231), (37011, Avery County, 17,806, 17,761), (37013, Beaufort County, 47,763, 47,799), (37015, Bertie County, 21,280, 21,250), (37017, Bladen County, 35,182, 35,194)]

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
path = 'Project 1 CSV Data/Poverty-Trends_1998-through-2016.csv'

data = pd.read_csv(path)

data
# Out:
#                 Geography Name    1998    1999    2000    2001    2002  \
# 0                United States  12.70%  11.90%  11.30%  11.70%  12.10%
# 1    North Carolina, Statewide  13.00%  12.30%  11.70%  11.90%  12.90%
# 2              Alamance County   9.80%   9.80%   9.40%  10.10%  10.70%
# 3             Alexander County  11.00%   9.90%   9.40%  10.20%  10.60%
# 4             Alleghany County  15.50%  13.90%  13.60%  14.40%  15.20%
# 5                 Anson County  19.20%  17.30%  16.80%  17.40%  18.10%
# 6                  Ashe County  16.30%  14.20%  13.90%  14.00%  15.00%
# 7                 Avery County  16.30%  14.90%  14.90%  15.90%  16.40%
# 8              Beaufort County  18.90%  18.90%  17.10%  16.80%  17.00%
# 9                Bertie County  23.40%  21.80%  20.80%  20.00%  20.10%
# 10               Bladen County  21.30%  20.10%  18.50%  17.70%  18.60%
# 11            Brunswick County  14.30%  13.70%  13.20%  13.50%  14.00%
# ...

# %%
data1 = data.drop(['Geography Name', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',], axis=1)
meck = data1.iloc[61]
meck
wake = data1.iloc[93]
wake
# Out:
# 2007     8.50%
# 2008     9.20%
# 2009    10.20%
# 2010    12.00%
# 2011    11.60%
# 2012    11.60%
# 2013    10.90%
# 2014    11.50%
# 2015    11.10%
# 2016     9.20%
# Name: 93, dtype: object

# %%
pov = data1.iloc[[0, 1, 61, 93]] 
pov
# Out:
#       2007    2008    2009    2010    2011    2012    2013    2014    2015  \
# 0   13.00%  13.20%  14.30%  15.30%  15.90%  15.90%  15.80%  15.50%  14.70%
# 1   14.30%  14.60%  16.20%  17.40%  17.80%  18.00%  17.80%  17.20%  16.40%
# 61  11.00%  10.90%  14.20%  15.60%  17.10%  16.10%  15.50%  15.20%  14.30%
# 93   8.50%   9.20%  10.20%  12.00%  11.60%  11.60%  10.90%  11.50%  11.10%
#
#       2016
# 0   14.00%
# 1   15.40%
# 61  12.30%
# 93   9.20%

# %%
pov['2007'] = pov['2007'].str.rstrip('%').astype('float')
pov['2008'] = pov['2008'].str.rstrip('%').astype('float')
pov['2009'] = pov['2009'].str.rstrip('%').astype('float')
pov['2010'] = pov['2010'].str.rstrip('%').astype('float')
pov['2011'] = pov['2011'].str.rstrip('%').astype('float')
pov['2012'] = pov['2012'].str.rstrip('%').astype('float')
pov['2013'] = pov['2013'].str.rstrip('%').astype('float')
pov['2014'] = pov['2014'].str.rstrip('%').astype('float')
pov['2015'] = pov['2015'].str.rstrip('%').astype('float')
pov['2016'] = pov['2016'].str.rstrip('%').astype('float')
# Out:
# C:\Users\Christopher Sloat\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Christopher Sloat\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Christopher Sloat\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
pov
# Out:
#     2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0   13.0  13.2  14.3  15.3  15.9  15.9  15.8  15.5  14.7  14.0
# 1   14.3  14.6  16.2  17.4  17.8  18.0  17.8  17.2  16.4  15.4
# 61  11.0  10.9  14.2  15.6  17.1  16.1  15.5  15.2  14.3  12.3
# 93   8.5   9.2  10.2  12.0  11.6  11.6  10.9  11.5  11.1   9.2

# %%
years = [2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]
us = pov.iloc[0]
nc = pov.iloc[1]
meckl = pov.iloc[2]
wak = pov.iloc[3]
plt.figure(figsize=(7,7))
# USA poverty rate
plt.plot(years, us , color="green", label="US Poverty Rate")

# NC poverty rate
plt.plot(years, nc, color="r", label="NC Poverty Rate")
# Mecklenburg poverty rate
plt.plot(years, meckl, color="lightskyblue", label="Mecklenburg Poverty Rate")
# Wake poverty rate
plt.plot(years, wak, color="magenta", label="Wake Poverty Rate")
# Place a legend on the chart in what matplotlib believes to be the "best" location
plt.legend(loc="best")
plt.gca().yaxis.grid(True)
plt.title("Poverty Rate")
plt.xlabel("Years")
plt.ylabel("% of people living in poverty")

# Print our chart to the screen
plt.savefig("Poverty Rate Graph")
plt.show()

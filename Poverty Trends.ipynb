# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
path = 'Project 1 CSV Data/Poverty-Trends_1998-through-2016.csv'

data = pd.read_csv(path)

data
# Out:
#                 Geography Name    1998    1999    2000    2001    2002  \
# 0                United States  12.70%  11.90%  11.30%  11.70%  12.10%
# 1    North Carolina, Statewide  13.00%  12.30%  11.70%  11.90%  12.90%
# 2              Alamance County   9.80%   9.80%   9.40%  10.10%  10.70%
# 3             Alexander County  11.00%   9.90%   9.40%  10.20%  10.60%
# 4             Alleghany County  15.50%  13.90%  13.60%  14.40%  15.20%
# 5                 Anson County  19.20%  17.30%  16.80%  17.40%  18.10%
# 6                  Ashe County  16.30%  14.20%  13.90%  14.00%  15.00%
# 7                 Avery County  16.30%  14.90%  14.90%  15.90%  16.40%
# 8              Beaufort County  18.90%  18.90%  17.10%  16.80%  17.00%
# 9                Bertie County  23.40%  21.80%  20.80%  20.00%  20.10%
# 10               Bladen County  21.30%  20.10%  18.50%  17.70%  18.60%
# 11            Brunswick County  14.30%  13.70%  13.20%  13.50%  14.00%
# ...

# %%
wake_data = data.loc[91]
meck_data = data.loc[61]
meck_data
wake_data
# Out:
# Geography Name    Union County
# 1998                     8.90%
# 1999                     8.90%
# 2000                     8.10%
# 2001                     8.00%
# 2002                     8.70%
# 2003                     9.30%
# 2004                     9.70%
# 2005                    10.50%
# 2006                     8.40%
# 2007                     7.90%
# 2008                     8.60%
# 2009                    10.90%
# 2010                     9.20%
# 2011                    10.60%
# 2012                    11.60%
# 2013                    10.30%
# 2014                    10.80%
# 2015                     9.70%
# 2016                     9.00%
# Name: 91, dtype: object

# %%
wmdata = data.iloc[[0, 1, 61, 91]] 
wmdata
gdata = wmdata.drop(['Geography Name'], axis=1)
gdata
# Out:
#       1998    1999    2000    2001    2002    2003    2004    2005    2006  \
# 0   12.70%  11.90%  11.30%  11.70%  12.10%  12.50%  12.70%  13.30%  13.30%
# 1   13.00%  12.30%  11.70%  11.90%  12.90%  13.40%  13.80%  14.90%  14.60%
# 61   9.90%   9.90%   8.80%   9.10%  10.60%  12.00%  12.80%  11.70%  11.50%
# 91   8.90%   8.90%   8.10%   8.00%   8.70%   9.30%   9.70%  10.50%   8.40%
#
#       2007    2008    2009    2010    2011    2012    2013    2014    2015  \
# 0   13.00%  13.20%  14.30%  15.30%  15.90%  15.90%  15.80%  15.50%  14.70%
# 1   14.30%  14.60%  16.20%  17.40%  17.80%  18.00%  17.80%  17.20%  16.40%
# 61  11.00%  10.90%  14.20%  15.60%  17.10%  16.10%  15.50%  15.20%  14.30%
# 91   7.90%   8.60%  10.90%   9.20%  10.60%  11.60%  10.30%  10.80%   9.70%
#
#       2016
# 0   14.00%
# 1   15.40%
# 61  12.30%
# 91   9.00%

# %%
tick_locations = [value for value in xaxis]
plt.xticks(tick_locations,  rotation="vertical")
years = gdata.keys()
us = gdata.iloc[0]
us = plt.plot(years, us, color="blue", label="World Average" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-05f714a05ceb> in <module>()
# ----> 1 tick_locations = [value for value in xaxis]
#       2 plt.xticks(tick_locations, rotation="vertical")
#       3 years = gdata.keys()
#       4 us = gdata.iloc[0]
#       5 us = plt.plot(years, us, color="blue", label="World Average" )
#
# NameError: name 'xaxis' is not defined

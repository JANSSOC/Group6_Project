# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
from pandas import DataFrame
import csv

# Import API key
from quandl_api_keys import api_key

# %%
# creating variables for api call
url = "https://www.quandl.com/api/v3/datasets/NAHB/HOI_AREA_CHARLOTTECONCORDGASTONIANCSC.csv?"
query_url = url + "api_key=" + api_key + add_params
add_params = "&start_date=2007-01-01&order=asc&collapse=annual"
data = pd.read_csv(query_url + add_params)
data
# Out:
#        Quarter  Median Price  Housing Opportunity Index  Median Income  \
# 0   2007-12-31         172.0                       62.9           60.2
# 1   2008-12-31         158.0                       72.2           64.3
# 2   2009-12-31         159.0                       75.2           66.5
# 3   2010-12-31         158.0                       77.6           67.2
# 4   2011-12-31         157.0                       78.0           67.5
# 5   2012-12-31         180.0                       74.8           68.5
# 6   2013-12-31         178.0                       70.2           64.1
# 7   2014-12-31         179.0                       70.3           64.2
# 8   2015-12-31         189.0                       73.1           67.2
# 9   2016-12-31         213.0                       69.3           67.0
# 10  2017-12-31         227.0                       68.7           70.7
# 11  2018-12-31         240.0                       65.2           74.1
#
#     National Rank  Regional Rank    Count
# ...

# %%
print(data['Median Price'])
# Out:
# 0     172.0
# 1     158.0
# 2     159.0
# 3     158.0
# 4     157.0
# 5     180.0
# 6     178.0
# 7     179.0
# 8     189.0
# 9     213.0
# 10    227.0
# 11    240.0
# Name: Median Price, dtype: float64

# %%
median_price = data['Median Price']
years = [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]


# # plotting data
fig, ax = plt.subplots()
ax.plot(years,median_price,color='steelblue',)
plt.xticks(years)
# today = datetime.today()

plt.gca().yaxis.grid(True)
# ax.grid()
fig.tight_layout()
plt.ylabel("Median Home Prices ($'s in Thousands)")
plt.title("Change in Median Home Prices 2007 - 2018")


# # saving figure
# plt.savefig("Output/Lat_vs_Temp", bbox_inches = 'tight')
plt.show()
